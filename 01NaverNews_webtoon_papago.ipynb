# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.9.3
# Summary: Screen-scraping library
# Home-page: http://www.crummy.com/software/BeautifulSoup/bs4/
# Author: Leonard Richardson
# Author-email: leonardr@segfault.org
# License: MIT
# Location: c:\users\ibk\anaconda3\lib\site-packages
# Requires: soupsieve
# Required-by: conda-build

# %% [markdown]
# ### 네이버 뉴스 제목 가져오기
#     * user-agent 헤더 값을 반드시 설정

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://news.naver.com/'
req_header_dict = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
}
res = requests.get(url, headers = req_header_dict)
print(res.status_code)
print(res.ok)

# %%
if res.ok:
    # 소스보기 했을 때 보여지는 텍스트
    html = res.text
    
    #BeautifulSoup 객체생성
    soup = BeautifulSoup(html, 'html.parser')
    print(len(soup.select("a[href*='read.naver']")))
    atag_list = soup.select("a[href*='read.naver']")
    print(type(atag_list))
    for atag in atag_list:
        # print(type(atag))
        # print(atag)
       
        if atag:
            title = atag.text.strip()
            # href = urljoin(url, atag['href'])
            print(title)
            
            print("------")
# Out:
# 199
# <class 'bs4.element.ResultSet'>
# 바이든 “양국 경쟁 충돌로 번지지 않게”...시진…
# ------
# '김혜경 낙상사고' 이후 계속된 잡음…'외출사진…
# ------
# [속보] 코로나19 위중증 495명 또 최다치…신규확진 2125명
# ------
# 초과세수 50조라는 與…기재부 "10조원대"
# ------
# 경기도 “일산대교 이용 혼란 최소화…행정력 동원해 무료화 추진”
# ------
# 인천시 파라다이스시티호텔에서 도심항공교통 첫선
# ------
# 총수 2세 지분율 높을수록 내부거래 비중 높아
# ------
#
# ------
# 與, 윤석열 겨냥 “대장동 숨은 몸통 비호” 공세
# ------
# 추미애 "윤석열 봐주기 수사…국회 법왜곡죄 통과시켜야"
# ------
# 이준석 "이재명, 자신에 비판적이면 보수?"
# ------
# 황교익, 돌연 지지 철회?…“이재명 지지한 적 없어”
# ------
# 오세훈 "시의회서 답변 기회 구걸 않겠다"…민주당과 설전
# ------
# 단호한 홍준표 "이준석 내치면 대선 진다"
# ------
#
# ------
# 가상자산 거래소 빗썸, '나 홀로' 사업자 승인 보류…왜?
# ------
# 아파트 대신 오피스텔 사는 수요자 들었다! ‘청라국제도시 아아파크’ 눈길
# ------
# 시행 30년 지났지만 노후생활비 수준 못미치는 국민연금…200만원↑수령자 고작 960명
# ------
# '아파트→빌라, 전세→월세'…옮겨가는 풍선효과
# ------
# "전기차 시장 확대 위해 가격 다운·충전 인프라 확보 시급"
# ------
# 유재석, 카카오엔터 주주 됐다…”유희열과 유증참여”
# ------
#
# ------
# 시민단체들 “오세훈 서울시장, 시민 참여 예산 삭감 철회해야”
# ------
# 평창 코로나19 확진자 발생
# ------
# 부산서 87명 확진…확진자 지속 증가에 ‘방역 경고등’
# ------
# 폐쇄됐던 대구 신천지 교회 다시 열리나...법원, 대구시장에 시설폐쇄 명령 취소 권고
# ------
# 평택시, 안중~수원 광교 운행 6800번 직행좌석 개통
# ------
# 방역당국 "아직 의료체계 여력 있다"
# ------
#
# ------
# “다이어트 성공 위해 먹어라”?…‘예방적 먹기’의 효과
# ------
# 차량용 반도체 공급난에…일부 기능 빼고 출고하는 완성車업계
# ------
# [날씨] 전국 쾌청한 가을…미세먼지 '보통'
# ------
# [날씨] 오늘 맑고 선선...수능일, 입시 추위 없어
# ------
# 멍냥이 오줌으로 요소수를? 계산해봤다
# ------
# [오후날씨 꿀팁] 온화한 오후…수능일, 중부엔 약한 비
# ------
# 동영상 기사
# ------
# 러시아 요격미사일에 위성 산산조각…미·영 "무책임"
# ------
# 중, 위드코로나 추세에도 '마이웨이'…"고립되지 않을 것"
# ------
# Fed 전현직 이사들 "미국 인플레 위험…테이퍼링 속도 높여야"
# ------
# 캐나다 서부 지역에 물폭탄…7000여명 대피 등 피해 속출
# ------
# 국경 연 태국, 영화 '비치' 촬영지 마야 베이도 3년만에 재개방
# ------
# 일본 부스터 샷 내달 개시·교차 접종 허용하기로
# ------
#
# ------
# '안테나' 판 유희열, 70억 카카오엔터에 베팅…'절친' 유재석도 동참
# ------
# 희귀한 롱다리 오징어 ‘빅핀오징어’ 포착
# ------
# '나는 한국인이다' 에픽게임즈 CEO, 韓방문해 '공정한 룰' 촉구
# ------
# 페이스북, 소리소문없이 '메타버스 기업' 사냥
# ------
# "안녕하게요" "매직한 하루 되시길" 디즈니플러스의 엉성한 고객상담은 진짜였다
# ------
# ‘4004 칩’ 50주년...인텔은 그때의 ‘왕관’을 되찾을 수 있을까
# ------
#
# ------
# "왕비 시해…생각보다 간단" 을미사변 日외교관 추정 편지  …
# ------
#
# ------
# “불법 자막보다 못한 수준” 한국 상륙 디즈니 ‘불만 폭발 …
# ------
#
# ------
# '경기 안방'도 놓치는 이재명... 윤석열과 지지율 자꾸  …
# ------
#
# ------
# 1시간30분을 10분으로 단축···'국내 최장' 보령해저터 …
# ------
#
# ------
# "강용석, 영상 안지우면 법원 간다" 김부선 뿔난 영상 뭐 …
# ------
#
# ------
# "커피값 300원 올렸더니 손님이…" 동네 커피숍의 '호소 …
# ------
#
# ------
# '돌아온 수능' 영어 듣기평가 시간엔 "항공기 이·착륙 잠 …
# ------
#
# ------
# "사전 예약만 1조5000억원 들어왔다"…테슬라 잡을 무서 …
# ------
#
# ------
# 국민연금 월 200만원 이상 수령자, 2018년 10명→올 …
# ------
#
# ------
# 진중권 “직장인은 아내가 몇바늘 꼬맨다고 하루 쉬지 않는다 …
# ------
#
# ------
# '文 경호원' 최영재 "아랍 왕족에 '백지수표' 제안받아"
# ------
#
# ------
# "아빠가 꽉 안아줬어요"…경비행기 추락 11세 소녀 생존
# ------
#
# ------
# "여가부 해체" 전효성 낯뜨거운 사진 띄운 신남성연대 논란
# ------
#
# ------
# 이재명 측 “검은 망토女 김혜경 아냐…수행원”
# ------
#
# ------
# 이철희 청 정무수석 "문 대통령 퇴임 때 '문전박대' 받길 …
# ------
# 동영상기사
# ------
# 오후 2시부터 요소수 재고 공개…산업용 전환 사용 추가 기 …
# ------
#
# ------
# [단독]  법무부만이 아니었다…부천·안산·제주서도 얼굴 정 …
# ------
#
# ------
# 식당 쑥대밭 만든 중학생 10명…담배 나무라자 몰려왔다
# ------
#
# ------
# “떨어진 옷장에 하반신 마비된 아내…5개월째 사과 없어”
# ------
#
# ------
# [NFT 감별사] ‘에스파’로 성공한 SM의 메타버스 실험 …
# ------
#
# ------
# 文 경호원 출신 최영재 “아랍 왕족에 백지수표 제안 받았다 …
# ------
#
# ------
# 독일, 걷잡을 수 없이 퍼지는 코로나19…"유례없는 속도"
# ------
#
# ------
# 이재명측 "올블랙 외출 사진, 김혜경씨 아닌 김씨 수행원"
# ------
#
# ------
# 배달까지 40분...퉁퉁 불어버린 면요리, 고객이 남긴 ‘ …
# ------
#
# ------
# [르포]"연식 6년이하 중고차 매물 끊겨, 고객 뚝"…매장 …
# ------
#
# ------
# "우리가 명성황후 시해‥생각보다 간단" 일본 외교관 추정  …
# ------
#
# ------
# 김동연 “서울대 학부 지방 이전하겠다…학종 폐지, 수능 2 …
# ------
# 동영상기사
# ------
# 이재명, 예결소위 의원들과 오찬…윤석열, 선대위 구상
# ------
#
# ------
# 경찰, 이재명 후보 아내 김혜경씨 취재기자들에게 '스토킹  …
# ------
#
# ------
# 고민정, '경희대 분교' 논란에 "평가절하 아냐…'을들의  …
# ------
#
# ------
# ‘제2 테슬라' 루시드, 사전예약자 1만7천명 돌파
# ------
#
# ------
# [속보] 중수본 "확진자 점진적으로 증가 양상…수목금 상황 …
# ------
#
# ------
# 文대통령, 임기 말 지지율 고공행진…靑 이철희 "문재인 효 …
# ------
#
# ------
# '신음 논란' 여성 BJ "남성 팬과 성관계 안해.. 조작 …
# ------
# 동영상기사
# ------
# 민주당, 김혜경 소문 배후로 “윤석열 캠프와 무관치 않다”
# ------
#
# ------
# 제네시스 'GV70 전기차', 19일 광저우모터쇼 세계 최 …
# ------
#
# ------
# "파주 요양병원, 윤석열 장모가 주도한 것 맞다"
# ------
#
# ------
# [속보] 김남국 "김혜경씨 관련 가짜뉴스 제보 479건…내 …
# ------
#
# ------
# [단독]국민MC 유재석, 카카오엔터 주주됐다.."유희열과  …
# ------
#
# ------
# 새로운 넷플릭스 시청법…쇼파에 누워 "알렉사, 뭐 좀 틀어 …
# ------
#
# ------
# 윤석열 52.7% vs 이재명 34.8%…양자대결 격차 1 …
# ------
#
# ------
# [영상] 종부세 납세 대상자 76만명 걱정하는 태영호
# ------
#
# ------
# "택시 기사가 휴대폰 찾아 준 사례금으로 20만원을 요구합 …
# ------
#
# ------
# "집값 떨어진다던 당신 말 믿었다가 벼락거지 됐잖아"…부동 …
# ------
#
# ------
# 더는 ‘요가복 샤넬’이라 부르지 마라!
# ------
#
# ------
# 몸속 염증 없애는 생활습관 4
# ------
#
# ------
# 여자들의 해방과 욕망을 찾아서: 섹스굿즈에서 한류까지
# ------
#
# ------
# 尹, 권성동 사무총장 확정…‘김종인 원톱 선대위’ 구성 막 …
# ------
#
# ------
# 이재명, 진중권에 "보수논객"…이준석 "하다하다 이제…웃기 …
# ------
#
# ------
# 윤석열 45.4% vs 이재명 34.1%…당선 가능성도 尹 …
# ------
#
# ------
# 김장훈‧영탁 출연... 22일 '강남가족콘서트' …
# ------
#
# ------
# [심상정 인터뷰] “차악을 고민하지 말고 최선을 선택하시라 …
# ------
#
# ------
# “딸이 엄마 뺨 때린 것, 왜 기사가 되나요”
# ------
#
# ------
# Vaccines from abroad don't cut i …
# ------
#
# ------
# [속보]산업용 요소수 차량용으로 전환 사용 불가…추가실험  …
# ------
#
# ------
# 대선 승자는 이미 결정됐다...단, 이재명도 윤석열도 아니 …
# ------
#
# ------
# 김동연 “李는 경제 기본도 모르고, 尹은 과거만 재단하던  …
# ------
#
# ------
# 국내 코로나 백신·치료제 임상시험 참가자는 방역패스 예외
# ------
#
# ------
# [CEO워치]'저격수에서 표적된' 김헌동, 험로는 지금부터
# ------
#
# ------
# “집값 오르는 소리 들린다”…신흥 주거 타운으로 거듭나는  …
# ------
#
# ------
# 가계대출 대란 속 은행은 호시절...3분기 누적 순익 15 …
# ------
#
# ------
# 중앙일보 온라인 회원 20만명... 홈피 개편 2개월만
# ------
#
# ------
# 답십리·을지로·세운지구…서울 도심 초역세권에 오피스텔 분양 …
# ------
#
# ------
# [강혜미의 스타트업 카페](19)프리랜서는 프리랜서로 대우 …
# ------
#
# ------
# 뱃살 빼주는 호르몬, '이 음식' 먹으면 잘 나와
# ------
#
# ------
# 정청래 "이해찬, 선대위 이끌 것… 김종인만큼 강하다"
# ------
#
# ------
# 대장동 머니, 쌍방울 전 대표에게로...'주가조작' 전 부 …
# ------
#
# ------
# [Feature] From bugs to delicacie …
# ------
#
# ------
# [우그그] 금광석 1톤에 금 5g, 폐휴대전화는 400g  …
# ------
#
# ------
# [Man&Wall] 경남의 자연암장 메카 의령 큰덤바위
# ------
#
# ------
# [우그그] 금광석 1톤에 금 5g, 폐휴대전화는 400g  …
# ------
#
# ------
# [Man&Wall] 경남의 자연암장 메카 의령 큰덤바위
# ------
#
# ------
# 김혜수가 ‘명품 직송’ 외치던 ‘발란’ 광고…프라다 광고  …
# ------
#
# ------
# 오늘 날씨는 '잎비' 내립니다…늦가을 큰 은행나무들의 선물
# ------
#
# ------
# 제주 반짝 명소 '이매진드 랜드스케이프 제주' 눈길
# ------
